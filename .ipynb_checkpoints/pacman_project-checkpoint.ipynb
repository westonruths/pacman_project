# %%
# %run pacman.py -p PacmanDQN -n 6000 -x 5000 -l smallClassic -g DirectionalGhost8 -e DirectionalGhost7 --frameTime 0 -q
# Out:
# Initialise DQN Agent
# #    1 | steps:    12 | steps_t:     0 | t: 0.011968 | r:  -489.000000 | e:   1.000000 | Q:        nan | won: False
# #    2 | steps:    24 | steps_t:     0 | t: 0.023936 | r:  -478.000000 | e:   1.000000 | Q:        nan | won: False
# #    3 | steps:    34 | steps_t:     0 | t: 0.033909 | r:  -476.000000 | e:   1.000000 | Q:        nan | won: False
# #    4 | steps:    45 | steps_t:     0 | t: 0.050864 | r:  -499.000000 | e:   1.000000 | Q:        nan | won: False
# #    5 | steps:    55 | steps_t:     0 | t: 0.062832 | r:  -476.000000 | e:   1.000000 | Q:        nan | won: False
# #    6 | steps:    64 | steps_t:     0 | t: 0.072808 | r:  -475.000000 | e:   1.000000 | Q:        nan | won: False
# #    7 | steps:    78 | steps_t:     0 | t: 0.088764 | r:  -458.000000 | e:   1.000000 | Q:        nan | won: False
# #    8 | steps:    90 | steps_t:     0 | t: 0.101728 | r:  -478.000000 | e:   1.000000 | Q:        nan | won: False
# ...
